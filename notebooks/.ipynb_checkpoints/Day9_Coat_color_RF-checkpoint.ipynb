# %% [markdown]
# ### Throwback: which SNPs are associated with mouse hair color again?
#
# Remember the GWAS task, where we investigated which SNPs were significantly associated with the coat color of mice? Machine learning ties in well with this task. We know random forests are useful to determine the importance of different features when classifying samples. We could ask a random forest to predict hair color from genotype data, and then look at what features it considered important while doing it.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score, cross_val_predict
from sklearn import metrics as sme

# %% [markdown]
# Load the genotype and color data. Make sure you index the genotype data explicitly by passing `index_col="Locus"` to the csv reader.

# %%
genotype = pd.read_csv("files/dataS4.txt", sep="\t", comment="@", index_col="Locus")
colors = pd.read_csv("files/phenotype.csv", index_col=0, names=["color"], na_values='x').dropna()['color']

# %%
colors
# Out:
# C57BL/6J    4.0
# DBA/2J      1.0
# B6D2F1      4.0
# D2B6F1      4.0
# BXD1        1.0
# BXD2        4.0
# BXD5        3.0
# BXD6        3.0
# BXD8        3.0
# BXD9        1.0
# BXD11       4.0
# BXD12       3.0
# BXD13       2.0
# BXD14       4.0
# BXD15       2.0
# BXD16       3.0
# BXD18       3.0
# BXD19       3.0
# BXD20       4.0
# BXD21       1.0
# BXD22       3.0
# BXD23       4.0
# BXD24       2.0
# BXD24a      2.0
# BXD25       2.0
# BXD27       2.0
# BXD28       2.0
# BXD29       3.0
# BXD30       1.0
# BXD31       4.0
#            ...
# BXD191      4.0
# BXD192      2.0
# BXD193      2.0
# BXD194      2.0
# BXD195      2.0
# BXD196      2.0
# BXD197      2.0
# BXD198      3.0
# BXD199      4.0
# BXD200      2.0
# BXD201      1.0
# BXD202      3.0
# BXD203      2.0
# BXD204      4.0
# BXD205      3.0
# BXD206      1.0
# BXD207      4.0
# BXD208      3.0
# BXD209      2.0
# BXD210      4.0
# BXD211      3.0
# BXD212      3.0
# BXD213      3.3
# BXD214      3.5
# BXD215      3.0
# BXD216      1.0
# BXD217      4.0
# BXD218      4.0
# BXD219      4.0
# BXD220      1.0
# Name: color, Length: 199, dtype: float64

# %% [markdown]
# Split the genotype data into two dataframes: one should contain the metadata (first 3 columns) and the other the actual genotype data. Call them `geno_metadata` and `geno`.
#
# Remember, `sklearn` takes samples in rows, and our samples correspond to mice strains here, so transpose `geno`. Also make sure that the indices of the `geno` and `color` DFs line up with each other: only keep the intersection of their indices. Index objects support intersection.

# %%
geno_metadata = genotype.iloc[:, :3]
geno = genotype.iloc[:,3:].T

# %%
geno.index.intersection(colors.index)

colors = colors.loc[geno.index.intersection(colors.index)]
geno = geno.loc[geno.index.intersection(colors.index)]
#geno_metadata = geno_metadata.loc[geno.index]

geno.shape
# Out:
# (90, 3811)

# %% [markdown]
# Encode the B/D/H/U genotype information with numbers. You can use -1/0/0/1 or 0/1/1/2 for B/H/U/D respectively. Either way, it's best to encode H with a value between B and D since it stands for hybrid.
#
# As for encoding colors: they are already numbers. We won't even transform them to the binary black/non-black labels like we did on day 3, we will just feed it them to the predictor as they are. Let the random forest figure out the associations for black/grey/white/brown.

# %%
encode = {'B' : 0, 'D' : 1, 'H': 1, 'U' : 2}
geno_enc = geno

geno_enc = geno_enc.applymap(encode.get)
geno_enc.shape
# Out:
# (90, 3811)

# %% [markdown]
# Train a random forest classifier with all the data. Make sure you use a lot of trees in that forest (a few thousand should be good) so we can get fine-grained values for feature importances. The more decision trees you run the data on, the clearer it gets which features it tests most often.

# %%
clf = RandomForestClassifier(n_estimators=10000, random_state=0)
clf.fit(geno_enc, colors)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10000, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %% [markdown]
# Now take the feature importance vector, and add it to the `geno_metadata` DataFrame as a new column. Sort by that column (obviously descending), and look at the most important SNP ids. Compare them with your GWAS data -- no need to load anything, just look at the Manhattan plot from day 3.

# %%
importances = pd.Series(clf.feature_importances_ , index = geno_metadata.index)
geno_metadata['importance'] = importances

geno_metadata.sort_values('importance', ascending=False)
# Out:
#                Chr       cM          Mb  importance
# Locus
# rs13477796       4   41.281   78.698063    0.014379
# rs3708061        4   41.281   80.950126    0.013659
# rs13480283       9   45.892   75.877786    0.013334
# rs3685573        9   46.179   76.102533    0.012830
# rs3724833        9   45.892   74.735876    0.012397
# rs3658567        4   40.995   76.484833    0.012392
# rs3725904        9   46.179   76.983761    0.012354
# rs13480279       9   45.606   74.382952    0.011503
# rs3670437        9   45.319   73.954057    0.011468
# CEL-4_74066970   4   40.708   75.438626    0.010671
# rs13477785       4   40.995   75.774916    0.010619
# rs13480277       9   45.319   73.928872    0.010255
# CEL-4_74121566   4   40.708   75.493222    0.010069
# rs3674482        9   47.074   77.217283    0.009631
# rs6167970        9   45.033   73.368885    0.008982
# rs13480291       9   47.361   77.779276    0.008877
# rs13480288       9   47.361   77.247378    0.008807
# rs13480276       9   45.033   73.688973    0.008614
# CEL-4_72665819   4   39.813   74.037476    0.008462
# rs13477805       4   42.501   81.934379    0.008372
# rs13477804       4   42.501   81.604580    0.008260
# rs6217039        9   47.647   78.046015    0.008123
# gnf09.074.193    9   47.647   79.902981    0.007795
# gnf04.071.066    4   39.813   75.249698    0.007530
# rs13477825       4   43.945   87.106964    0.006991
# rs13480268       9   43.813   72.030418    0.006832
# rs3674783        4   43.086   83.447453    0.006800
# rs4227771        9   43.813   72.952358    0.006722
# rs6258088        4   43.086   82.262281    0.006593
# CEL-4_82641197   4   43.372   84.012618    0.006477
# ...             ..      ...         ...         ...
# rs6191721       10   67.856   91.382290    0.000034
# rs13480002       8   72.933  117.676135    0.000034
# rs13475985       1   70.553   94.845961    0.000034
# rs13477467       3   86.325  144.305923    0.000034
# rs4193194       16   47.770   61.491008    0.000033
# rs13483683      19   74.511   55.602429    0.000033
# rs13481617      12   79.706  103.658501    0.000033
# rs13483200      18    1.444    9.902164    0.000033
# D1Mit145         1  105.500  169.225247    0.000032
# rs3022802        1   47.866   65.092380    0.000032
# rs13479203       7   27.397   47.074572    0.000032
# rs13479624       8   10.658   16.859146    0.000031
# rs3701429        6   22.331   30.223154    0.000031
# rs3693605       12   79.420  103.550016    0.000031
# rs3696200        1   75.200  107.242003    0.000030
# rs13482327      14   47.749   97.600346    0.000030
# rs13482873      17    8.694   11.606729    0.000030
# rs6399765        1  105.213  169.192841    0.000029
# rs3673816        9   24.534   47.039894    0.000029
# rs13476004       1   72.871   99.958650    0.000029
# rs8260975        7   35.151   53.682777    0.000028
# rs3716572       19   64.407   50.798144    0.000028
# rs3678179        1    7.248   15.498263    0.000028
# rs13476012       1   74.329  101.801485    0.000028
# rs3692096       11   91.766  108.093002    0.000027
# rs4228112       10    2.669   12.729006    0.000026
# rs3695581        1   80.415  120.637061    0.000024
# rs13480459       9  110.699  122.175147    0.000024
# rs13483670      19   66.803   52.514624    0.000022
# rs3023711       12   97.813  117.417765    0.000021
#
# [3811 rows x 4 columns]

# %%
def manhattenplot(df_manhatten, colToPrint):
    offsets = df_manhatten.groupby('Chr', sort=False).Mb.max().cumsum()

    offsets -= offsets.loc['1']
    Mb = df_manhatten.apply(lambda x: x.Mb + offsets.loc[x.Chr], axis=1)
    
    colors = {'1':'darkred', '2':'darkorange', '3':'lightgreen', '4':'green', '5':'cyan', '6':'blue', '7':'purple', '8':'violet', '9':'darkred', '10':'darkorange', '11':'lightgreen', '12':'green' , '13':'cyan', '14':'blue', '15':'purple', '16':'violet', '17':'darkred', '18':'darkorange', '19':'lightgreen', 'X':'green'}

    df_manhattenplot = df_manhatten.insert(3, 'Mb', df_manhatten_totalmb)
    plt.subplots(figsize=(20,5))

    plt.scatter(x=df_manhattenplot['Mb'], y=-np.log10(df_manhattenplot[colToPrint]), c=df_manhatten['Chr'].apply(lambda x: colors[x]))
    plt.title('Manhattan Plot')
    plt.xlabel('Chromosoms')
    plt.ylabel('-log p')
    #plt.xticks(np.arange(0, 20, step=0.2), df_manhatten['Chr'], rotation = 90)

# %% [markdown]
# If you took the effort to load that mouse genotype and color data, you might as well take a peek at the performance of the predictor. Calculate a cross-validated accuracy score, and create a confusion matrix for the four colors. You can lower the number of trees used by an order of magnitude, since cross-validation makes things more time intensive.

# %%
cv_probs = cross_val_predict(clf, geno_enc, colors, cv = StratifiedKFold(3, shuffle=True), method = 'predict_proba')

# %%
roc_results = sme.roc_curve(colors==1.0, cv_probs[:,0])
roc_curve = plt.plot(roc_results[0], roc_results[1])

# %% [markdown]
# And finally, create a ROC diagram. You know how to make them for binary classifiers... but this isn't a binary classification task. What should it look like when you have 4 labels instead of just 2?

# %%
roc_results = sme.roc_curve(colors==2.0, cv_probs[:,1])
roc_curve = plt.plot(roc_results[0], roc_results[1])
